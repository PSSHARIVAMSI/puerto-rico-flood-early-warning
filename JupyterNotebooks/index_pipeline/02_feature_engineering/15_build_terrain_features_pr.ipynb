# %% [markdown]
# # 15 Build Terrain Features for Puerto Rico
#
# This notebook is the guided Terrain Feature Pack v1 workflow for Puerto Rico.
#
# Use it in order:
# 1. inspect which sources were discovered locally
# 2. review the manual follow-up actions that still matter
# 3. place any needed downloads under `data/staging/terrain/`
# 4. run the terrain stage when you are ready
# 5. preview the outputs before deciding whether to ship

# %%
# Cell 1: Setup
import json
import sys
from pathlib import Path


def find_repo_root():
    p = Path.cwd().resolve()
    for candidate in [p, *p.parents]:
        if (candidate / "README.md").exists() and (candidate / "JupyterNotebooks").exists():
            return candidate
    return p


REPO_ROOT = find_repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from scripts.terrain.terrain_feature_pack import inspect_terrain_inputs, run_terrain_feature_pack

try:
    from IPython.display import display
except ImportError:
    display = print

print(f"Repo root: {REPO_ROOT}")
# Out:
# Repo root: /Users/sivamanisubrahmanyaharivamsipullipudi/Downloads/DEAN_690/Spring2026DEAN/Spring2026DAEN

# %%
# Cell 2: Inspect local terrain inputs before running the stage
inventory = inspect_terrain_inputs(repo_root=REPO_ROOT)
print(json.dumps(inventory, indent=2))
# Out:
# {
#   "config_version": "1.0",
#   "config_path": "config/terrain_spec_v1.yaml",
#   "staging_dir": "data/staging/terrain",
#   "staging_subdirs": [
#     "data/staging/terrain/boundaries",
#     "data/staging/terrain/dem",
#     "data/staging/terrain/streams",
#     "data/staging/terrain/coastal",
#     "data/staging/terrain/soils",
#     "data/staging/terrain/land_cover"
#   ],
#   "sources": {
#     "boundaries": {
#       "status": "local",
#       "paths": [
#         "data/staging/terrain/boundaries/pr_municipios_boundary.geojson",
#         "data/staging/terrain/boundaries/tl_2023_us_county.zip"
#       ],
#       "automation": "automated fetch fallback enabled"
#     },
#     "dem": {
#       "status": "missing",
#       "paths": [],
#       "manual_guidance": "Download Puerto Rico DEM tiles as GeoTIFF or IMG and place them under data/staging/terrain/dem/."
#     },
#     "streams": {
#       "status": "missing",
#       "paths": [],
#       "manual_guidance": "Place a local stream-flowline dataset under data/staging/terrain/streams/ as .gpkg, .geojson, .shp, .zip, or .gdb. The StreamStats webpage alone is not enough for this stage."
#     },
#     "coastal": {
#       "status": "missing",
#       "paths": [],
#       "manual_guidance": "Place NOAA Sea Level Rise depth rasters or inundation polygons under data/staging/terrain/coastal/ as .tif, .img, .gpkg, .geojson, .shp, .zip, or .gdb."
#     },
#     "soils": {
#       "status": "missing",
#       "paths": [],
#       "manual_guidance": "Place soils under data/staging/terrain/soils/ as .gpkg, .geojson, .shp, .zip, .gdb, .tif, or .img. For vectors, the layer needs a hydrologic-group field such as hydgrpdcd or HYDGROUP."
#     },
#     "land_cover": {
#       "status": "missing",
#       "paths": [],
#       "manual_guidance": "Place land-cover rasters under data/staging/terrain/land_cover/ as .tif, .tiff, or .img. NOAA C-CAP fits the default profile best; NLCD Puerto Rico works when the config profile is set or auto-detected."
#     }
#   },
#   "manual_actions": [
#     "Download Puerto Rico DEM tiles as GeoTIFF or IMG and place them under data/staging/terrain/dem/.",
#     "Place a local stream-flowline dataset under data/staging/terrain/streams/ as .gpkg, .geojson, .shp, .zip, or .gdb. The StreamStats webpage alone is not enough for this stage.",
#     "Place NOAA Sea Level Rise depth rasters or inundation polygons under data/staging/terrain/coastal/ as .tif, .img, .gpkg, .geojson, .shp, .zip, or .gdb.",
#     "Place soils under data/staging/terrain/soils/ as .gpkg, .geojson, .shp, .zip, .gdb, .tif, or .img. For vectors, the layer needs a hydrologic-group field such as hydgrpdcd or HYDGROUP.",
#     "Place land-cover rasters under data/staging/terrain/land_cover/ as .tif, .tiff, or .img. NOAA C-CAP fits the default profile best; NLCD Puerto Rico works when the config profile is set or auto-detected."
#   ]
# }

# %%
# Cell 3: Review discovered sources and manual follow-up actions
import pandas as pd

source_rows = []
for source_name, details in inventory["sources"].items():
    source_rows.append(
        {
            "source": source_name,
            "status": details.get("status"),
            "paths": "; ".join(details.get("paths", [])),
        }
    )

display(pd.DataFrame(source_rows))

if inventory["manual_actions"]:
    print("Manual follow-up actions:")
    for item in inventory["manual_actions"]:
        print(f"- {item}")
else:
    print("No blocking manual follow-up actions were generated by the inspection step.")
# Out:
#        source   status                                              paths
# 0  boundaries    local  data/staging/terrain/boundaries/pr_municipios_...
# 1         dem  missing
# 2     streams  missing
# 3     coastal  missing
# 4       soils  missing
# 5  land_cover  missing
# Manual follow-up actions:
# - Download Puerto Rico DEM tiles as GeoTIFF or IMG and place them under data/staging/terrain/dem/.
# - Place a local stream-flowline dataset under data/staging/terrain/streams/ as .gpkg, .geojson, .shp, .zip, or .gdb. The StreamStats webpage alone is not enough for this stage.
# - Place NOAA Sea Level Rise depth rasters or inundation polygons under data/staging/terrain/coastal/ as .tif, .img, .gpkg, .geojson, .shp, .zip, or .gdb.
# - Place soils under data/staging/terrain/soils/ as .gpkg, .geojson, .shp, .zip, .gdb, .tif, or .img. For vectors, the layer needs a hydrologic-group field such as hydgrpdcd or HYDGROUP.
# - Place land-cover rasters under data/staging/terrain/land_cover/ as .tif, .tiff, or .img. NOAA C-CAP fits the default profile best; NLCD Puerto Rico works when the config profile is set or auto-detected.

# %%
# Cell 4: Run the terrain stage when ready
RUN_TERRAIN_STAGE = False

if RUN_TERRAIN_STAGE:
    metadata = run_terrain_feature_pack(repo_root=REPO_ROOT)
    print(json.dumps(metadata, indent=2))
else:
    print("Set RUN_TERRAIN_STAGE = True when you are ready to generate terrain outputs.")
# Out:
# Set RUN_TERRAIN_STAGE = True when you are ready to generate terrain outputs.

# %%
# Cell 5: Preview outputs after a successful run
import pandas as pd

if "metadata" not in globals():
    print("Run Cell 4 first to generate metadata and terrain outputs.")
else:
    csv_path = REPO_ROOT / metadata["output_files"]["attribute table (CSV)"]
    preview = pd.read_csv(csv_path)
    display(preview.head(10))
    print(f"Rows: {len(preview)}")
# Out:
# Run Cell 4 first to generate metadata and terrain outputs.
